# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket-Kumar-7/MATLlab/blob/main/Matlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x=np.linspace(0,5,11)
print(x)
y=x**2
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x,y)
plt.title("First Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.subplot(2,2,1)

plt.subplot(2,2,2)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
fig=plt.figure(figsize=(10,8),dpi=100)
axis1=fig.add_axes([.5,.5,.5,1])
axis1.plot(x,y)
axis2=fig.add_axes([.1,.1,.3,.3])
axis2.plot(x**2,y**2)

# %%
plt.scatter(x,y)

# %%
fig=plt.figure()
plt.hist(y)
# Out:
# (array([4., 1., 1., 1., 1., 0., 1., 0., 1., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b48674a9550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7b48674d1a30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7b48674d1430>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b48674d1ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b48674d2120>],
#  'means': []}

# %%
fig=plt.figure()
axis=fig.add_axes([.1,.1,.8,.8])
axis.plot(x,y)
plt.savefig('simpleplot.png')

# %%
import matplotlib.image as mg
img=mg.imread(r'/content/Untitled design.png')
img
plt.imshow(img)
# plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1524204837.py in <cell line: 0>()
#       1 import matplotlib.image as mg
# ----> 2 img=mg.imread(r'/content/Untitled design.png')
#       3 img
#       4 plt.imshow(img)
#       5 # plt.axis('off')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in imread(fname, format)
#    1500             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501             )
# -> 1502     with img_open(fname) as image:
#    1503         return (_pil_png_to_float_array(image)
#    1504                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.12/dist-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     133         if is_path(fp):
#     134             # filename
# --> 135             self.fp = open(fp, "rb")
# ...

# %%
crop_img=img[0:400,0:1000]
crop_img
plt.imshow(crop_img)
plt.axis('off')

# %%
plt.plot(x,y,color='Red')

# %%
import seaborn as sbn
import matplotlib.pyplot as plt

df=sbn.load_dataset('tips')
df

# %%
df['size'].unique()

# %%
plt.subplot(1,2,1)
sbn.histplot(df['total_bill'],bins=50,kde=True)
plt.subplot(1,2,2)
sbn.histplot(df['tip'],bins=50,kde=True)

# %%
sbn.jointplot(x=df['total_bill'],y=df['tip'],kind='reg')

# %%
sbn.pairplot(df,hue='sex',palette='rainbow')

# %%
sbn.rugplot(df)

# %%
sbn.barplot(x=df['sex'],y=df['total_bill'],estimator=np.sum)

# %%
sbn.countplot(x=df['sex'],hue=df['day'])

# %%
sbn.boxplot(x=df['tip'],y=df['day'])

# %%
sbn.violinplot(y=df['total_bill'],x=df['day'])

# %%
sbn.stripplot(x=df['day'],y=df['total_bill'])

# %%
sbn.swarmplot(y=df['total_bill'],x=df['day'])

# %%
flights=sbn.load_dataset('flights')
flights

# %%
tips=sbn.load_dataset('tips')
tips

# %%
tipscore=tips[['total_bill','tip','size']]
tipscore

# %%
tipmatrix_data=tipscore.corr()
tipmatrix_data

# %%
sbn.heatmap(tipmatrix_data,annot=True)

# %%
sbn.clustermap(tipmatrix_data)

# %%
flight_pivot=flights.pivot_table(values='passengers',index='month',columns='year')
flight_pivot

# %%
sbn.heatmap(flight_pivot)

# %%
sbn.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',markers=['o','v'],scatter_kws={'s':100})

# %%
# !pip install cufflinks

# %%
# !pip install plotly

# %%
import cufflinks as cf
from plotly.offline import iplot
import plotly.express as px
tips=sbn.load_dataset('tips')
tips

# %%
fig=px.line(tips,y='total_bill')
fig.show()

# %%
tips.groupby('day')['tip'].mean()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df=pd.read_csv(r'/content/IPL.csv')
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
print(df.size)
df.shape
# Out:
# 1480
# (74, 20)

# %%
len(df.columns)
# Out:
# 20

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
df[df['match_winner']==df['match_winner'].max()].head(1)['match_winner']
# Out:
# 4    Rajasthan
# Name: match_winner, dtype: object

# %%
match_wins=df['match_winner'].value_counts()
type(match_wins)
# Out:
# pandas.core.series.Series

# %%
sbn.barplot(y=match_wins.index,x=match_wins.values,palette='rainbow')
plt.title('Most winner Team')
plt.xlabel('Matches')
plt.ylabel('Teams')
# Out:
# /tmp/ipython-input-1389292836.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sbn.barplot(y=match_wins.index,x=match_wins.values,palette='rainbow')
# Text(0, 0.5, 'Teams')

# %%
sbn.countplot(x=df['toss_decision'],palette='rainbow')
plt.title('Toss Decision')

# %%
sbn.boxplot(x=df['match_winner'],y=df['toss_winner'])
vs=df[df['toss_winner']==df['match_winner']]['match_winner'].count()
vs
percentage=(vs*100)/df.shape[0]
percentage.round(2)

# %%
wicket_win=df[df['won_by']=='Wickets']
print(wicket_win.count()['match_id'])
run_win=df[df['won_by']=='Runs']
(run_win.count())['match_id']
sbn.countplot(x=df['won_by'])

# %%
count=df['player_of_the_match'].value_counts().head(10)
sbn.barplot(y=count.index,x=count.values)
plt.xlabel('Numbers')
count[count.values==count.max()]

# %%
from numpy._core.defchararray import index
df.head(1)
top_2=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
# top_2.index[0]/
top_2

# %%
df['higest_wickets']=df['best_bowling_figure'].apply(lambda x:x.split('--')[0]).astype(int)
df['higest_wickets'][0]
# Out:
# np.int64(3)

# %%
top_bowlers=df.groupby('best_bowling')['higest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind='barh')
plt.xlabel('Wickets')
plt.ylabel('Bowlers')
plt.title('Bowler and Wickets')
# Out:
# Text(0.5, 1.0, 'Bowler and Wickets')

# %%
venue=df['venue'].value_counts()
venue
sbn.barplot(y=venue.index,x=venue.values)
# Out:
# <Axes: ylabel='venue'>

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
high_margin=df.groupby('won_by')['margin'].max().sort_values(ascending=False).head(5)
high_margin.plot(kind='barh')
df[df['won_by']=='Runs'].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
individual_score=df.groupby('top_scorer')['highscore'].max().sort_values(ascending=False).head(10)
individual_score.plot(kind='barh')
individual_score.index[0]
df[df['highscore']==df['highscore'].max()][['player_of_the_match','highscore']]
# Out:
#    player_of_the_match  highscore
# 65     Quinton de Kock        140

# %%
best_bowling_figure_bowler=df.groupby('best_bowling')['best_bowling_figure'].max().sort_values(ascending=False).head()
# sbn.barplot(y=best_bowling_figure_bowler.index,x=best_bowling_figure_bowler.values)
best_bowling_figure_bowler.index[0]
# Out:
# 'Yuzvendra Chahal'

# %%
df[df['higest_wickets']==df['higest_wickets'].max()][['best_bowling','higest_wickets']].head(1)
# Out:
#         best_bowling  higest_wickets
# 29  Yuzvendra Chahal               5
